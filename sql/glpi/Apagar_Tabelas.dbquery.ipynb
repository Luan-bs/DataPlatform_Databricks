-- %%
-- -- DROP TABLE workspace.glpi.d_users;

-- -- DROP TABLE workspace.glpi.d_status;

-- DROP TABLE workspace.glpi.f_tickets;

-- DROP TABLE workspace.glpi.f_ticketsatisfactions;

-- DROP TABLE workspace.glpi.p_tickets_users;

-- DROP TABLE workspace.glpi.silver_tickets;

-- DROP TABLE workspace.glpi.silver_users;

-- DROP TABLE workspace.glpi.silver_tickets_users;

-- DROP TABLE workspace.glpi.silver_tickets_tickets;

-- DROP TABLE workspace.glpi.silver_ticketsatisfactions;

-- DROP TABLE workspace.glpi.bronze_tickets;

-- DROP TABLE workspace.glpi.bronze_users;

-- DROP TABLE workspace.glpi.bronze_tickets_users;

-- DROP TABLE workspace.glpi.bronze_tickets_tickets;

-- DROP TABLE workspace.glpi.bronze_ticketsatisfactions;
