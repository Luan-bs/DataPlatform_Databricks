-- %%
-- Gold
DROP TABLE IF EXISTS glpi.gold_chamados.d_users;
DROP TABLE IF EXISTS glpi.gold_chamados.d_status;
DROP TABLE IF EXISTS glpi.gold_chamados.f_tickets;
DROP TABLE IF EXISTS glpi.gold_chamados.f_ticketsatisfactions;
DROP TABLE IF EXISTS glpi.gold_chamados.p_tickets_users;

-- Silver
DROP TABLE IF EXISTS glpi.silver.tickets;
DROP TABLE IF EXISTS glpi.silver.users;
DROP TABLE IF EXISTS glpi.silver.tickets_users;
DROP TABLE IF EXISTS glpi.silver.tickets_tickets;
DROP TABLE IF EXISTS glpi.silver.ticketsatisfactions;

-- Bronze
DROP TABLE IF EXISTS glpi.bronze.glpi_tickets;
DROP TABLE IF EXISTS glpi.bronze.glpi_users;
DROP TABLE IF EXISTS glpi.bronze.glpi_tickets_users;
DROP TABLE IF EXISTS glpi.bronze.glpi_tickets_tickets;
DROP TABLE IF EXISTS glpi.bronze.glpi_ticketsatisfactions;
